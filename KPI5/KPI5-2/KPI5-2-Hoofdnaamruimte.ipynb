# %%
import numpy as np
import pandas as pd

file = 'WPNLHoofdnaamruimteArtikel-KBdienst-KBurl_definitief_20022018.txt'
data = pd.read_csv(file, sep='ZZZZ', encoding='utf-8', engine='python')

# uit bovenstaand bestand een (dataframe) genereren met de volgende opbouw: 
#      KBLabel                ;KBFullname;                                   ; NumLinks_hnr; NumWPArtikelen_hnr; Sortorder
# bv:  Delpher Kranten Basis;Delpher - Kranten 1618-1995 (Basiscollectie)    ;9061         ;3834               ;1

# KBLabel: kolom 2 van bovenstaand txt-bestand

# Maak pandas dataframe aan -  we know we're gonna have 29 rows of data
numberOfRows = 29
# create dataframe
data2 = pd.DataFrame(index=np.arange(0, numberOfRows), columns=('KBLabel', 'KBFullname', 'NumLinks_hnr', 'NumWPArtikelen_hnr', 'Sortorder'))

# 1 - Delpher Kranten Basis
NumberofLinks_DelpherKrantenBasis=len(data[data['KBdienst']=='Delpher Kranten Basis'])
NumberUniqueWPArticles_DelpherKrantenBasis = len(data.WikipediaArtikel[data['KBdienst']=='Delpher Kranten Basis'].unique())
#Voeg rij voor rij toe aan dataframe
data2.loc[0] = ["Delpher Kranten Basis", "Delpher - Kranten 1618-1995 (Basiscollectie)", NumberofLinks_DelpherKrantenBasis, NumberUniqueWPArticles_DelpherKrantenBasis, 1]

# 2 Delpher Boeken Basis;Delpher - Boeken 17e t/m 20e eeuw (Basiscollectie);;;2
NumberofLinks_DelpherBoekenBasis=len(data[data['KBdienst']=='Delpher Boeken Basis'])
NumberUniqueWPArticles_DelpherBoekenBasis = len(data.WikipediaArtikel[data['KBdienst']=='Delpher Boeken Basis'].unique())
data2.loc[1] = ["Delpher Boeken Basis", "Delpher - Boeken 17e t/m 20e eeuw (Basiscollectie)", NumberofLinks_DelpherBoekenBasis, NumberUniqueWPArticles_DelpherBoekenBasis, 2]

#3 Delpher Tijdschriften;Delpher - Tijdschriften 19e en 20e eeuw;;;3
NumberofLinks_DelpherTijdschriften=len(data[data['KBdienst']=='Delpher Tijdschriften'])
NumberUniqueWPArticles_DelpherTijdschriften = len(data.WikipediaArtikel[data['KBdienst']=='Delpher Tijdschriften'].unique())
data2.loc[2] = ["Delpher Tijdschriften", "Delpher - Tijdschriften 19e en 20e eeuw", NumberofLinks_DelpherTijdschriften, NumberUniqueWPArticles_DelpherTijdschriften, 3]

#4 Delpher Boeken Google;Delpher - Boeken tot 1874 (Googlecollectie);;;4
NumberofLinks_DelpherBoekenGoogle=len(data[data['KBdienst']=='Delpher Boeken Google'])
NumberUniqueWPArticles_DelpherBoekenGoogle = len(data.WikipediaArtikel[data['KBdienst']=='Delpher Boeken Google'].unique())
data2.loc[3] = ["Delpher Boeken Google", "Delpher - Boeken tot 1874 (Googlecollectie)", NumberofLinks_DelpherBoekenGoogle, NumberUniqueWPArticles_DelpherBoekenGoogle, 4]

#5 Delpher Overig;Delpher - Rest - o.a. homepage,  statische pagina's;;;5
NumberofLinks_DelpherOverig=len(data[data['KBdienst']=='Delpher Overig'])
NumberUniqueWPArticles_DelpherOverig = len(data.WikipediaArtikel[data['KBdienst']=='Delpher Overig'].unique())
data2.loc[4] = ["Delpher Overig", "Delpher - Rest - o.a. homepage,  statische pagina's", NumberofLinks_DelpherOverig, NumberUniqueWPArticles_DelpherOverig, 5]

#6 Delpher Radiobulletins;Delpher - Radiobulletins van het ANP;;;6
NumberofLinks_DelpherRadiobulletins=len(data[data['KBdienst']=='Delpher Radiobulletins'])
NumberUniqueWPArticles_DelpherRadiobulletins = len(data.WikipediaArtikel[data['KBdienst']=='Delpher Radiobulletins'].unique())
data2.loc[5] = ["Delpher Radiobulletins", "Delpher - Radiobulletins van het ANP", NumberofLinks_DelpherRadiobulletins, NumberUniqueWPArticles_DelpherRadiobulletins, 6]

#7 Totaal Delpher;Totaal Delpher, alle inhoud;;;7 
NumberofLinks_TotaalDelpher = NumberofLinks_DelpherKrantenBasis + NumberofLinks_DelpherBoekenBasis + NumberofLinks_DelpherTijdschriften + NumberofLinks_DelpherBoekenGoogle + NumberofLinks_DelpherOverig + NumberofLinks_DelpherRadiobulletins
NumberUniqueWPArticles_TotaalDelpher = len(data.WikipediaArtikel[(data['KBdienst'] == 'Delpher Kranten Basis')|(data['KBdienst'] == 'Delpher Boeken Basis')|(data['KBdienst'] == 'Delpher Tijdschriften')|(data['KBdienst'] == 'Delpher Boeken Google')|(data['KBdienst'] == 'Delpher Overig')|(data['KBdienst'] == 'Delpher Radiobulletins')].unique())
data2.loc[6] = ["Totaal Delpher", "Totaal Delpher, alle inhoud", NumberofLinks_TotaalDelpher, NumberUniqueWPArticles_TotaalDelpher, 7]

#8 DBNL;Digitale Bibliotheek der Nederlandse Letteren;;;8
NumberofLinks_DBNL=len(data[data['KBdienst']=='DBNL'])
NumberUniqueWPArticles_DBNL = len(data.WikipediaArtikel[data['KBdienst']=='DBNL'].unique())
data2.loc[7] = ["DBNL", "Digitale Bibliotheek der Nederlandse Letteren", NumberofLinks_DBNL, NumberUniqueWPArticles_DBNL, 8]

#9 Literatuurgeschiedenis;Literatuurgeschiedenis.nl (project van DBNL);;;9
NumberofLinks_Literatuurgeschiedenis=len(data[data['KBdienst']=='Literatuurgeschiedenis'])
NumberUniqueWPArticles_Literatuurgeschiedenis = len(data.WikipediaArtikel[data['KBdienst']=='Literatuurgeschiedenis'].unique())
data2.loc[8] = ["Literatuurgeschiedenis", "Literatuurgeschiedenis.nl (project van DBNL)", NumberofLinks_Literatuurgeschiedenis, NumberUniqueWPArticles_Literatuurgeschiedenis, 9]

#10 DBNL Schrijvers;DBNL Schrijvers - Hermans, Du Perron, Ter Braak;;;10   
NumberofLinks_DBNLSchrijvers=len(data[data['KBdienst']=='DBNL Schrijvers'])
NumberUniqueWPArticles_DBNLSchrijvers = len(data.WikipediaArtikel[data['KBdienst']=='DBNL Schrijvers'].unique())
data2.loc[9] = ["DBNL Schrijvers", "DBNL Schrijvers - Hermans, Du Perron, Ter Braak", NumberofLinks_DBNLSchrijvers, NumberUniqueWPArticles_DBNLSchrijvers, 10]

#11 GvN;Het Geheugen van Nederland;;;11
NumberofLinks_GvN=len(data[data['KBdienst']=='GvN'])
NumberUniqueWPArticles_GvN = len(data.WikipediaArtikel[data['KBdienst']=='GvN'].unique())
data2.loc[10] = ["GvN", "Het Geheugen van Nederland", NumberofLinks_GvN, NumberUniqueWPArticles_GvN, 11]

#12 SGD;Staten-Generaal Digitaal;;;12
NumberofLinks_SGD=len(data[data['KBdienst']=='SGD'])
NumberUniqueWPArticles_SGD = len(data.WikipediaArtikel[data['KBdienst']=='SGD'].unique())
data2.loc[11] = ["SGD", "Staten-Generaal Digitaal", NumberofLinks_SGD, NumberUniqueWPArticles_SGD, 12]

#13 KB-cat;Algemene KB-catalogus;;;13
NumberofLinks_KBcat=len(data[data['KBdienst']=='KB-cat'])
NumberUniqueWPArticles_KBcat = len(data.WikipediaArtikel[data['KBdienst']=='KB-cat'].unique())
data2.loc[12] = ["KB-cat", "Algemene KB-catalogus", NumberofLinks_KBcat, NumberUniqueWPArticles_KBcat, 13]

#14 kb.nl;KB.nl;;;14
NumberofLinks_kbnl=len(data[data['KBdienst']=='kb.nl'])
NumberUniqueWPArticles_kbnl = len(data.WikipediaArtikel[data['KBdienst']=='kb.nl'].unique())
data2.loc[13] = ["kb.nl", "KB.nl", NumberofLinks_kbnl, NumberUniqueWPArticles_kbnl, 14]

#15 Poortman;Wijsbegeerte in Nederland (Poortmans repertorium);;;15
NumberofLinks_Poortman=len(data[data['KBdienst']=='Poortman'])
NumberUniqueWPArticles_Poortman = len(data.WikipediaArtikel[data['KBdienst']=='Poortman'].unique())
data2.loc[14] = ["Poortman", "Wijsbegeerte in Nederland (Poortmans repertorium)", NumberofLinks_Poortman, NumberUniqueWPArticles_Poortman, 15]

#16 DBNG;Digitale Bibliografie Nederlandse Geschiedenis;;;16
NumberofLinks_DBNG=len(data[data['KBdienst']=='DBNG'])
NumberUniqueWPArticles_DBNG = len(data.WikipediaArtikel[data['KBdienst']=='DBNG'].unique())
data2.loc[15] = ["DBNG", "Digitale Bibliografie Nederlandse Geschiedenis", NumberofLinks_DBNG, NumberUniqueWPArticles_DBNG, 16]

#17 Bibliopolis;Bibliopolis (boekgeschiedenis);;;17
NumberofLinks_Bibliopolis=len(data[data['KBdienst']=='Bibliopolis'])
NumberUniqueWPArticles_Bibliopolis = len(data.WikipediaArtikel[data['KBdienst']=='Bibliopolis'].unique())
data2.loc[16] = ["Bibliopolis", "Bibliopolis (boekgeschiedenis)", NumberofLinks_Bibliopolis, NumberUniqueWPArticles_Bibliopolis, 17]

#18 MVH;Middeleeuwse Verluchte Handschriften;;;18
NumberofLinks_MVH=len(data[data['KBdienst']=='MVH'])
NumberUniqueWPArticles_MVH = len(data.WikipediaArtikel[data['KBdienst']=='MVH'].unique())
data2.loc[17] = ["MVH", "Middeleeuwse Verluchte Handschriften", NumberofLinks_MVH, NumberUniqueWPArticles_MVH, 18]

#19 MMDC;Medieval Manuscripts in Dutch Collections;;;19
NumberofLinks_MMDC=len(data[data['KBdienst']=='MMDC'])
NumberUniqueWPArticles_MMDC = len(data.WikipediaArtikel[data['KBdienst']=='MMDC'].unique())
data2.loc[18] = ["MMDC", "Medieval Manuscripts in Dutch Collections", NumberofLinks_MMDC, NumberUniqueWPArticles_MMDC, 19]

#20 Watermark.kb.nl;Watermerken in Incunabelen uit de Lage Landen;;;20
NumberofLinks_Watermarkkbnl=len(data[data['KBdienst']=='Watermark.kb.nl'])
NumberUniqueWPArticles_Watermarkkbnl = len(data.WikipediaArtikel[data['KBdienst']=='Watermark.kb.nl'].unique())
data2.loc[19] = ["Watermark.kb.nl", "Watermerken in Incunabelen uit de Lage Landen", NumberofLinks_Watermarkkbnl, NumberUniqueWPArticles_Watermarkkbnl, 20]

#21 Netuit.kb.nl;Net Uit - Nederlandse Bibliografie Weeklijst (archief);;;21
NumberofLinks_Netuitkbnl=len(data[data['KBdienst']=='Netuit.kb.nl'])
NumberUniqueWPArticles_Netuitkbnl = len(data.WikipediaArtikel[data['KBdienst']=='Netuit.kb.nl'].unique())
data2.loc[20] = ["Netuit.kb.nl", "Net Uit - Nederlandse Bibliografie Weeklijst (archief)", NumberofLinks_Netuitkbnl, NumberUniqueWPArticles_Netuitkbnl, 21]

#22 Lijsten.kb.nl;KB Lijsten en verzamelingen;;;22
NumberofLinks_Lijstenkbnl=len(data[data['KBdienst']=='Lijsten.kb.nl'])
NumberUniqueWPArticles_Lijstenkbnl = len(data.WikipediaArtikel[data['KBdienst']=='Lijsten.kb.nl'].unique())
data2.loc[21] = ["Lijsten.kb.nl", "KB Lijsten en verzamelingen", NumberofLinks_Lijstenkbnl, NumberUniqueWPArticles_Lijstenkbnl, 22]

#23 BLTVN;Bibliografie van de Literaire Tijdschriften in Vlaanderen en Nederland;;;23
NumberofLinks_BLTVN=len(data[data['KBdienst']=='BLTVN'])
NumberUniqueWPArticles_BLTVN = len(data.WikipediaArtikel[data['KBdienst']=='BLTVN'].unique())
data2.loc[22] = ["BLTVN", "Bibliografie van de Literaire Tijdschriften in Vlaanderen en Nederland", NumberofLinks_BLTVN, NumberUniqueWPArticles_BLTVN, 23]

#24 Literatuurplein;Literatuurplein;;;24
NumberofLinks_Literatuurplein=len(data[data['KBdienst']=='Literatuurplein'])
NumberUniqueWPArticles_Literatuurplein = len(data.WikipediaArtikel[data['KBdienst']=='Literatuurplein'].unique())
data2.loc[23] = ["Literatuurplein", "Literatuurplein", NumberofLinks_Literatuurplein, NumberUniqueWPArticles_Literatuurplein, 24]

#25 Bibliotheek.nl;Bibliotheek.nl;;;25
NumberofLinks_Bibliotheeknl=len(data[data['KBdienst']=='Bibliotheek.nl'])
NumberUniqueWPArticles_Bibliotheeknl = len(data.WikipediaArtikel[data['KBdienst']=='Bibliotheek.nl'].unique())
data2.loc[24] = ["Bibliotheek.nl", "Bibliotheek.nl", NumberofLinks_Bibliotheeknl, NumberUniqueWPArticles_Bibliotheeknl, 25]

#26 Leesplein;Leesplein;;;26
NumberofLinks_Leesplein=len(data[data['KBdienst']=='Leesplein'])
NumberUniqueWPArticles_Leesplein = len(data.WikipediaArtikel[data['KBdienst']=='Leesplein'].unique())
data2.loc[25] = ["Leesplein", "Leesplein", NumberofLinks_Leesplein, NumberUniqueWPArticles_Leesplein, 26]

#27 Vakantiebieb;Vakantiebieb;;;27
NumberofLinks_Vakantiebieb=len(data[data['KBdienst']=='Vakantiebieb'])
NumberUniqueWPArticles_Vakantiebieb = len(data.WikipediaArtikel[data['KBdienst']=='Vakantiebieb'].unique())
data2.loc[26] = ["Vakantiebieb", "Vakantiebieb", NumberofLinks_Vakantiebieb, NumberUniqueWPArticles_Vakantiebieb, 27]

#28 Digitale etalages;Digitale etalages;;;28
NumberofLinks_Digitaleetalages=len(data[data['KBdienst']=='Digitale etalages'])
NumberUniqueWPArticles_Digitaleetalages = len(data.WikipediaArtikel[data['KBdienst']=='Digitale etalages'].unique())
data2.loc[27] = ["Digitale etalages", "Digitale etalages", NumberofLinks_Digitaleetalages, NumberUniqueWPArticles_Digitaleetalages, 28]

# 29 - Totaal alle KB-diensten
NumberofLinks_KBTotaal=len(data)
NumberUniqueWPArticles_KBTotaal = len(data.WikipediaArtikel.unique())
data2.loc[28] = ["Totaal KBsites", "Totaal alle KB-websites", NumberofLinks_KBTotaal, NumberUniqueWPArticles_KBTotaal, 29]

print(data2)
# Out:
#                    KBLabel                                         KBFullname  \
# 0    Delpher Kranten Basis       Delpher - Kranten 1618-1995 (Basiscollectie)
# 1     Delpher Boeken Basis  Delpher - Boeken 17e t/m 20e eeuw (Basiscollec...
# 2    Delpher Tijdschriften            Delpher - Tijdschriften 19e en 20e eeuw
# 3    Delpher Boeken Google        Delpher - Boeken tot 1874 (Googlecollectie)
# 4           Delpher Overig  Delpher - Rest - o.a. homepage,  statische pag...
# 5   Delpher Radiobulletins               Delpher - Radiobulletins van het ANP
# 6           Totaal Delpher                        Totaal Delpher, alle inhoud
# 7                     DBNL      Digitale Bibliotheek der Nederlandse Letteren
# 8   Literatuurgeschiedenis       Literatuurgeschiedenis.nl (project van DBNL)
# 9          DBNL Schrijvers    DBNL Schrijvers - Hermans, Du Perron, Ter Braak
# 10                     GvN                         Het Geheugen van Nederland
# ...

# %%
import numpy as np
import pandas as pd
from matplotlib.ticker import ScalarFormatter
from matplotlib import pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

myboldfont = {'fontname':'DIN-Bold'}
myregularfont = {'family' : 'DIN-RegularAlternate'}
plt.rc('font', **myregularfont)

# set jupyter's max row and columns display
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 10)
# set jupyter's max column width to 50
pd.set_option('display.max_colwidth', 50)

#list of colors by name: https://xkcd.com/color/rgb/

#Draw plot
bar_width2 = 0.65

plotdata=data2[['KBFullname', 'NumLinks_hnr','NumWPArtikelen_hnr']]
ax2= plotdata.plot(x='KBFullname',kind='barh', width=bar_width2, figsize=(21,15), color=["xkcd:medium blue","xkcd:dark blue"], 
    fontsize=12, rot=0)

# Set title and main x,y labels
ax2.set_title("Links en artikelen in Nederlandstalige Wikipedia o.b.v. KB-websites (hoofdnaamruimte, 20-02-2018)",
             fontsize=22, color="xkcd:navy", fontweight='bold', loc='left', **myboldfont).set_position([-0.205,1.03])
ax2.set_xlabel("Aantal (logaritmisch)", fontsize=18, color="xkcd:dark grey", **myboldfont)
ax2.set_ylabel("Naam van website", fontsize=18, color="xkcd:dark grey", **myboldfont)

#Make x axis log scaled
ax2.set_xscale('log')

ax2.invert_yaxis()

ax2.get_xaxis().set_major_formatter(ScalarFormatter())

#set x ticks
xticklist=[1,10,100,1000,10000,20000]
ax2.set_xticks(xticklist)

#Make x and y tick labels black
for i in list(range(0,len(xticklist))): 
    ax2.get_xticklabels()[i].set_color('xkcd:black') 
for j in list(range(0,len(data2))):    
    ax2.get_yticklabels()[j].set_color('xkcd:black')

# Make bigger tick labels for 'Totaal Delper, alle inhoud' and 'Totaal alle KB-diensten'
ax2.get_yticklabels()[6].set_fontsize(18)
ax2.get_yticklabels()[28].set_fontsize(18)

#Add custom colored bars for totals KB and Delpher
#Totaal alle KB-diensten
ax2.get_children()[28].set_color("xkcd:light mustard")
ax2.get_children()[57].set_color("xkcd:mustard")
#Totaal Delpher, alle inhoud
ax2.get_children()[6].set_color("xkcd:teal")
ax2.get_children()[35].set_color("xkcd:dark teal")

##Add numbers at ends of bars
for i in ax2.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax2.text(1.05*i.get_width(),i.get_y()+0.32, i.get_width(), fontsize=10, color='#1e0a33', **myboldfont)

# Add legend
ax2.legend(('Aantal links (URLs) in de Nederlandstalige Wikipedia\nnaar deze website','Aantal unieke artikelen in de Nederlandstalige Wikipedia\nmet (een of meer) links naar deze website')
           ,bbox_to_anchor=(0.9, 0.4), labelspacing=1.0, frameon=True, fontsize=14)    
    
#Add logos
logo_kb = plt.imread('KBlogoNL_300px.png')
logo_wp= plt.imread('logo_wp_120px.png')
logo_bysa=plt.imread('by-sa_120px.png')
ax2.figure.figimage(logo_wp, 11, 48, alpha=.5, zorder=1,resize=False)
ax2.figure.figimage(logo_kb, 145,7, alpha=.5, zorder=1,resize=False)
ax2.figure.figimage(logo_bysa, 10, 2, alpha=.5, zorder=1,resize=False)
